# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

(X_train,y_train),(X_test,y_test) = keras.datasets.mnist.load_data()
X_train.shape

X_train
X_test
y_train

import matplotlib.pyplot as plt
plt.imshow(X_train[0])

import matplotlib.pyplot as plt
plt.imshow(X_train[1])

import matplotlib.pyplot as plt
plt.imshow(X_train[2])

import matplotlib.pyplot as plt
plt.imshow(X_train[8])

X_train[0]

X_train = X_train/255
X_test = X_test/255
X_train[0]

model = Sequential()

model.add(Flatten(input_shape=(28, 28)))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='sparse_categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=10,validation_split=0.2)

model.predict(X_test)

y_prob = model.predict(X_test)
y_prob
y_prob.argmax(axis=1)

y_pred = y_prob.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

history = model.fit(X_train,y_train,epochs=10,validation_split=0.2)

y_prob = model.predict(X_test)

y_pred = y_prob.argmax(axis=1)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
X_test

plt.imshow
plt.imshow(X_test[0])

model.predict(X_test[0].reshape(1,28,28))

model.predict(X_test[0].reshape(1,28,28)).argmax(axis=1)
plt.imshow(X_test[1])
plt.imshow(X_test[3])
plt.imshow(X_test[4])
model.predict(X_test[1].reshape(1,28,28))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.2890 - accuracy: 0.9166 - val_loss: 0.1795 - val_accuracy: 0.9474
# Epoch 2/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.1297 - accuracy: 0.9612 - val_loss: 0.1206 - val_accuracy: 0.9652
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0885 - accuracy: 0.9736 - val_loss: 0.0975 - val_accuracy: 0.9712
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0653 - accuracy: 0.9802 - val_loss: 0.0978 - val_accuracy: 0.9724
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0505 - accuracy: 0.9848 - val_loss: 0.0910 - val_accuracy: 0.9751
# Epoch 6/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0399 - accuracy: 0.9876 - val_loss: 0.0918 - val_accuracy: 0.9746
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0303 - accuracy: 0.9908 - val_loss: 0.0857 - val_accuracy: 0.9763
# Epoch 8/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0245 - accuracy: 0.9926 - val_loss: 0.0917 - val_accuracy: 0.9757
# Epoch 9/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0205 - accuracy: 0.9940 - val_loss: 0.0935 - val_accuracy: 0.9758
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0933 - val_accuracy: 0.9760
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0143 - accuracy: 0.9956 - val_loss: 0.1036 - val_accuracy: 0.9755
# Epoch 2/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.1104 - val_accuracy: 0.9742
# Epoch 3/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.1039 - val_accuracy: 0.9766
# Epoch 4/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.1116 - val_accuracy: 0.9750
# Epoch 5/10
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.1331 - val_accuracy: 0.9704
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1083 - val_accuracy: 0.9781
# Epoch 7/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.1161 - val_accuracy: 0.9776
# Epoch 8/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.1382 - val_accuracy: 0.9737
# Epoch 9/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.1575 - val_accuracy: 0.9689
# Epoch 10/10
# 1500/1500 [==============================] - 8s 5ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.1253 - val_accuracy: 0.9758
# 313/313 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# array([[1.8446365e-14, 1.4893857e-10, 1.0000000e+00, 3.0454727e-13,
#         1.2285525e-31, 7.6873857e-16, 5.7828417e-13, 6.6089429e-23,
#         1.8189908e-15, 6.4522882e-27]], dtype=float32)
